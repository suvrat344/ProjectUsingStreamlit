# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("startup_funding.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df[df["investors"].str.contains("Tiger Global Management")].groupby("startup")["amount"].sum().sort_values(ascending=False)
# Out:
# startup
# BYJU’S                   1650.00
# Shopclues                 825.00
# Saavn                     825.00
# Delhivery                 701.25
# Moglix                    495.00
# Zenoti                    412.50
# Zovi.com / Little App     412.50
# Grey Orange               247.50
# Zo Rooms                  247.50
# CleverTap                 214.50
# BlackBuck                 206.25
# Chargebee                 148.50
# OkCredit                  127.88
# INDwealth                 123.75
# Lybrate                    84.15
# Razorpay                   74.25
# Cube26                     63.52
# LocalOye                   41.25
# Vedantu                    41.25
# Chaayos                    24.75
# Name: amount, dtype: float64

# %%
df[df["investors"].str.contains("Tiger Global Management")].groupby("vertical")["amount"].sum().head().plot(kind="pie")
# Out:
# <Axes: ylabel='amount'>

# %%
df["year"] = df["date"].dt.year
df[df["investors"].str.contains("Tiger Global Management")].groupby("year")["amount"].sum().head().plot(kind="line")
# Out:
# <Axes: xlabel='year'>

# %%
round(df["amount"].max())
# Out:
# 32175

# %%
df.groupby("startup")["amount"].max().sort_values(ascending=False).head(n=1).values[0]
# Out:
# 32175.0

# %%
df.groupby("startup")["amount"].sum().mean()
# Out:
# 129.10241289198606

# %%
df.groupby("startup")["startup"].count().sum()
# Out:
# 2818

# %%
df["startup"].nunique()
# Out:
# 2296

# %%
temp_df
# Out:
#     year  month    amount   x_axis
# 0   2015      4   8080.88   4-2015
# 1   2015      5   2641.12   5-2015
# 2   2015      6   4302.29   6-2015
# 3   2015      7  12450.86   7-2015
# 4   2015      8   8776.43   8-2015
# 5   2015      9  12123.55   9-2015
# 6   2015     10   2103.43  10-2015
# 7   2015     11   7399.87  11-2015
# 8   2015     12   2523.25  12-2015
# 9   2016      1   5774.00   1-2016
# 10  2016      2   2734.80   2-2016
# 11  2016      3   2553.85   3-2016
# 12  2016      4   2094.98   4-2016
# 13  2016      5   2803.65   5-2016
# 14  2016      6   1647.00   6-2016
# 15  2016      7   1926.77   7-2016
# 16  2016      8   4406.19   8-2016
# 17  2016      9   1991.24   9-2016
# 18  2016     10   1958.92  10-2016
# 19  2016     11   2144.95  11-2016
# 20  2016     12   1544.73  12-2016
# 21  2017      1   2089.18   1-2017
# 22  2017      2   2433.39   2-2017
# 23  2017      3  18680.30   3-2017
# 24  2017      4   6042.25   4-2017
# 25  2017      5  14740.01   5-2017
# ...
